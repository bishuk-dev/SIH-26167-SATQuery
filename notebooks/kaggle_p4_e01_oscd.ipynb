# %% [markdown]
# # P4-E01 OSCD deterministic validation

# %%
import os, subprocess
from pathlib import Path
REPO_DIR = Path('/kaggle/working/satquery')
REPO_URL = os.environ['SATQUERY_REPO_URL']
if not (REPO_DIR / '.git').is_dir():
    subprocess.run(['git', 'clone', '--depth', '1', REPO_URL, str(REPO_DIR)], check=True)

# %%
import sys
sys.path.insert(0, str(REPO_DIR))
source_root = Path(os.environ['OSCD_ROOT'])
if not source_root.is_dir(): raise FileNotFoundError(source_root)
print('environment and source verified; invoke tested P4-E01 evaluator here')
