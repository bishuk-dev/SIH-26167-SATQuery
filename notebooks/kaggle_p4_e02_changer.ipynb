# %% [markdown]
# # P4-E02 ChangerEx validation

# %%
import os, subprocess
from pathlib import Path
REPO_DIR = Path('/kaggle/working/satquery')
if not (REPO_DIR / '.git').is_dir(): subprocess.run(['git', 'clone', '--depth', '1', os.environ['SATQUERY_REPO_URL'], str(REPO_DIR)], check=True)

# %%
import sys
sys.path.insert(0, str(REPO_DIR))
source_root = Path(os.environ['LEVIR_CD_ROOT'])
if not source_root.is_dir(): raise FileNotFoundError(source_root)
print('environment and source verified; invoke tested P4-E02 evaluator here')
